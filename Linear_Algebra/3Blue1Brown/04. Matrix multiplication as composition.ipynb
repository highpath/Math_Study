# %% [markdown]
# > *It is my experience that proofs involving matrices can be shorten by 50% if one throws the matrices out.*
# > \- Emil Artin

# %% [markdown]
# # 1. Composition

# %% [markdown]
# # 2. Matrix Multiplication

# %% [markdown]
# # 3. Associativity
