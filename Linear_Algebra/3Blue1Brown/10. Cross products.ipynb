# %% [markdown]
# > *\"Every dimension is special."*
#
# > \- Jeff Lagarias

# %% [markdown]
# # 1. Standard introduction

# %% [markdown]
# - $\vec{v} \times \vec{w} = \vec{p}$
# - length: area
# - direction: right hand rule

# %% [markdown]
# # 2. Computation
#
# - $\begin{bmatrix} v_1 \\ v_2 \\ v_3 \end{bmatrix} \times
# \begin{bmatrix} w_1 \\ w_2 \\ w_3 \end{bmatrix} = det(
# \begin{bmatrix} \hat{i}&v_1&w_1 \\ \hat{j}&v_2& w_2 \\ \hat{k} &v_3&w_3 \end{bmatrix})$

# %% [markdown]
# # print("hi")

# %% [markdown]
# $ a \sim \vec{i} bc$
