# %% [markdown]
# > *Calvin: You know, I don't think math is a science, I think it's a religion.*
# > *Hobbes: A religion?*
# > *Yeah. All these equations are like miracles. You take two numbers and when you add them, they magically become one NEW number! No one can say how it happens. You either believce it or you don't.*

# %% [markdown]
# # 1. Dot product
# ## 1) Standard way
# - pairing up all of the coordinates, multiplying those pairs together, adding the result
# - Two vectors of the same dimension
# - $\begin{bmatrix} 2\\7\\1 \end{bmatrix} \cdot \begin{bmatrix} 8\\2\\8 \end{bmatrix} = 2\cdot8+7\cdot2+1\cdot8$
#
# ## 2) Geometric interpretation
# - $\vec{v} \cdot \vec{w} = $ (Length of projected $\vec{w}$)(Length of $\vec{v}$) (if projection is opposite direction, negative)
# - project w onto the line that passes through the rigin and the tip of v
# - order doesn't matter

# %% [markdown]
# # 2. Duality
#
# - 1x2 matrix vs 2d vector

# %% [markdown]
# # Duality
# - Natural-but-surprising correspondence
# - vector = linear transformation
# - linear transformation from space to one dimension = certain vector in that space
# - dotting two vectors together = translate one of them into transformation
