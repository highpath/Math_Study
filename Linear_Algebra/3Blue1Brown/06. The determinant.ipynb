# %% [markdown]
# > *\"The purpose of computation is **insight**, not **numbers**."*
#
# > \- Richard Hamming

# %% [markdown]
# # 1. Determinant
# - the factor by which a linear transformation changes any area

# %% [markdown]
# # 2. Negative Determinant
# - flipping space: invert the orientation of space
# - check order of $\hat{i}$ and $\hat{j}$

# %% [markdown]
# # 3. Three-dimension
# - Volume of this Parallelepiped
# - right hand rule: Positive

# %% [markdown]
# # 4.
# $det(\begin{bmatrix} a&b \\ c&d\end{bmatrix})= ad-bc$
